# %% [markdown]
# # Woz U Data Science Program
# ## Final Project
# ## Leo Jacquez and Sarah Mangrum

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind
from scipy.stats import boxcox
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %% [markdown]
# # Import Data

# %%
attrition = pd.read_csv('Final_dataset_Attrition.csv')

# url: https://www.kaggle.com/singhnproud77/hr-attrition-prediction/notebook
# site source

# %% [markdown]
# # Question Setup
#
# * Working with IBM HR attrition data, who is most likely to quit their job at IBM?
# * Use findings to help forecast attrition rates and recommend possible solutions to minimize employee turnover and interruptions in work flow where viable.

# %% [markdown]
# # View Data and Gather Information for Analyses

# %% [markdown]
# ## View beginning and end of data file

# %%
attrition.head()
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
# 2   45        No  Travel_Rarely  Research & Development                 6
# 3   23        No  Travel_Rarely                   Sales                 2
# 4   22        No  Travel_Rarely  Research & Development                15
#
#    Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0    Male               2         1  Laboratory Technician                3
# 1    Male               3         1     Research Scientist                4
# 2    Male               3         3      Research Director                1
# 3    Male               3         1   Sales Representative                1
# 4  Female               3         1  Laboratory Technician                4
#
#    ... Date_of_Hire  Date_of_termination   Status_of_leaving Mode_of_work  \
# 0  ...   21-01-2021                  NaN              Salary       OFFICE
# 1  ...   13-03-2021                  NaN       Work Accident          WFH
# 2  ...   23-01-2021                  NaN           Dept.Head          WFH
# 3  ...   25-04-2021                  NaN       Work Accident       OFFICE
# 4  ...   14-06-2021                  NaN  Better Opportunity          WFH
#
#    Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode  Unnamed: 32
# 0       4            2             No       Job Event   Contract          NaN
# 1       5            2             No       Recruiter  Part Time          NaN
# 2       1            3             No       Job Event   Contract          NaN
# 3       1            0            Yes       Recruiter   FullTime          NaN
# 4       5            2             No       Job Event   Contract          NaN
#
# [5 rows x 33 columns]

# %%
attrition.tail()
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
#       Gender  JobInvolvement  JobLevel                    JobRole  \
# 1465    Male               2         4                    Manager
# 1466    Male               3         5                    Manager
# 1467    Male               2         5                    Manager
# 1468    Male               3         4            Sales Executive
# 1469  Female               3         3  Healthcare Representative
#
#       JobSatisfaction  ... Date_of_Hire  Date_of_termination  \
# 1465                1  ...   05-06-1987                  NaN
# 1466                1  ...   20-01-1985                  NaN
# 1467                4  ...   17-02-1985                  NaN
# 1468                3  ...   29-06-1984                  NaN
# 1469                4  ...   08-02-1981                  NaN
#
#       Status_of_leaving Mode_of_work  Leaves  Absenteeism  Work_accident  \
# 1465             Salary       OFFICE       3            2             No
# 1466      Work Accident          WFH       1            1             No
# 1467      Work Accident       OFFICE       2            1             No
# 1468   Work Environment          WFH       2            2            Yes
# 1469   Work Environment          WFH       4            3            Yes
#
#       Source_of_Hire   Job_mode  Unnamed: 32
# 1465      Job Portal  Part Time          NaN
# 1466         Walk-in   FullTime          NaN
# 1467       Recruiter  Part Time          NaN
# 1468       Job Event  Part Time          NaN
# 1469      Job Portal   FullTime          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ## View available dataset information
# * columns names
# * no. of rows: 1470
# * no. of columns: 33
# * variable types

# %%
attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   object
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   object
#  14  PercentSalaryHike        1470 non-null   int64
#  15  PerformanceRating        1470 non-null   int64
#  16  StockOptionLevel         1470 non-null   int64
#  17  TotalWorkingYears        1470 non-null   int64
#  18  TrainingTimesLastYear    1470 non-null   int64
#  19  YearsAtCompany           1470 non-null   int64
#  20  YearsSinceLastPromotion  1470 non-null   int64
#  21  YearsWithCurrManager     1470 non-null   int64
#  22  Higher_Education         1470 non-null   object
#  23  Date_of_Hire             1470 non-null   object
#  24  Date_of_termination      0 non-null      float64
#  25  Status_of_leaving        1470 non-null   object
#  26  Mode_of_work             1470 non-null   object
#  27  Leaves                   1470 non-null   int64
#  28  Absenteeism              1470 non-null   int64
#  29  Work_accident            1470 non-null   object
#  30  Source_of_Hire           1470 non-null   object
#  31  Job_mode                 1470 non-null   object
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(2), int64(17), object(14)
# memory usage: 379.1+ KB

# %% [markdown]
# # Variable Description Key
# * "Age" = The age of the employee
# * "Attrition" = Whether the employee has attrited or not
# * "BusinessTravel" = Whether the employee used to travel for business or not
# * "Department" = Which department the employee was employed under
# * "DistanceFromHome" = The distance the employee travels to reach job on a day to day basis
# * "Gender" = Gender of the employee
# * "JobInvolvement" = The involvement rating of an employee over the job handled
# * "JobLevel" = Level at which the employee is working
# * "JobRole" = The roles and resposibilites of the employee
# * "JobSatisfaction" = Satisfaction rating of the employee for the job
# * "MaritalStatus" = Marital status of the employee
# * "MonthlyIncome" = Monthly income of the employee
# * "NumCompaniesWorked" = Number of companies the employees has worked for
# * "OverTime" = Whether working Overtime or not
# * "PercentSalaryHike" = Percentage salary hike since their appointment in the company
# * "PerformanceRating" = Performance rating
# * "StockOptionLevel" = Level of opted for sharing the stock
# * "TotalWorkingYears" = Total years worked by the employee
# * "TrainingTimesLastYear" = How many trainings the employee has undergone
# * "YearsAtCompany" = Years spent at the present organization
# * "YearsSinceLastPromotion" = Time in years since last promotion
# * "YearsWithCurrManager" = Years working under their current manager
# * "Higher_Education" = Higher education level of the employee
# * "Date_of_Hire" = Date of hire of the employee in the current organization
# * "Date_of_termination" = Date of termination from the organization
# * "Status_of_leaving" = Reason for leaving the organization
# * "Mode_of_work" = WFH or WFO
# * "Leaves" = Total permitted leaves taken by the employee
# * "Absenteeism" = Total days absent for the employee
# * "Work_accident" = Work accident if any
# * "Source_of_hire" = Source of hire
# * "Job_Mode" = Working full time, part time or contractual

# %% [markdown]
# ## View descriptive statistics of the dataset

# %%
attrition.describe()
# Out:
#                Age  DistanceFromHome  JobInvolvement     JobLevel  \
# count  1470.000000       1470.000000     1470.000000  1470.000000
# mean     36.923810          9.192517        2.729932     2.063946
# std       9.135373          8.106864        0.711561     1.106940
# min      18.000000          1.000000        1.000000     1.000000
# 25%      30.000000          2.000000        2.000000     1.000000
# 50%      36.000000          7.000000        3.000000     2.000000
# 75%      43.000000         14.000000        3.000000     3.000000
# max      60.000000         29.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count      1470.000000    1470.000000         1470.000000        1470.000000
# mean          2.728571    6502.931293            2.693197          15.209524
# std           1.102846    4707.956783            2.498009           3.659938
# min           1.000000    1009.000000            0.000000          11.000000
# 25%           2.000000    2911.000000            1.000000          12.000000
# 50%           3.000000    4919.000000            2.000000          14.000000
# 75%           4.000000    8379.000000            4.000000          18.000000
# max           4.000000   19999.000000            9.000000          25.000000
#
#        PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# count        1470.000000       1470.000000        1470.000000
# mean            3.153741          0.793878          11.279592
# std             0.360824          0.852077           7.780782
# min             3.000000          0.000000           0.000000
# 25%             3.000000          0.000000           6.000000
# 50%             3.000000          1.000000          10.000000
# 75%             3.000000          1.000000          15.000000
# max             4.000000          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count            1470.000000     1470.000000              1470.000000
# mean                2.799320        7.008163                 2.187755
# std                 1.289271        6.126525                 3.222430
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        3.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager  Date_of_termination       Leaves  Absenteeism  \
# count           1470.000000                  0.0  1470.000000  1470.000000
# mean               4.123129                  NaN     2.568707     1.525170
# std                3.568136                  NaN     1.716171     1.097856
# min                0.000000                  NaN     0.000000     0.000000
# 25%                2.000000                  NaN     1.000000     1.000000
# 50%                3.000000                  NaN     3.000000     2.000000
# 75%                7.000000                  NaN     4.000000     2.000000
# max               17.000000                  NaN     5.000000     3.000000
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
# Look at the mean/average of the dataset variables
attrition.mean()
# Out:
# Age                          36.923810
# DistanceFromHome              9.192517
# JobInvolvement                2.729932
# JobLevel                      2.063946
# JobSatisfaction               2.728571
# MonthlyIncome              6502.931293
# NumCompaniesWorked            2.693197
# PercentSalaryHike            15.209524
# PerformanceRating             3.153741
# StockOptionLevel              0.793878
# TotalWorkingYears            11.279592
# TrainingTimesLastYear         2.799320
# YearsAtCompany                7.008163
# YearsSinceLastPromotion       2.187755
# YearsWithCurrManager          4.123129
# Date_of_termination                NaN
# Leaves                        2.568707
# Absenteeism                   1.525170
# Unnamed: 32                        NaN
# dtype: float64

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Check data for missing values

# %%
attrition.isna().sum()
# Out:
# Age                           0
# Attrition                     0
# BusinessTravel                0
# Department                    0
# DistanceFromHome              0
# Gender                        0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# NumCompaniesWorked            0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# Higher_Education              0
# Date_of_Hire                  0
# Date_of_termination        1470
# Status_of_leaving             0
# Mode_of_work                  0
# Leaves                        0
# Absenteeism                   0
# Work_accident                 0
# Source_of_Hire                0
# Job_mode                      0
# Unnamed: 32                1470
# dtype: int64

# %% [markdown]
# ## Drop/Remove NaN columns and date column

# %%
attrition = attrition.drop(["Date_of_Hire", "Date_of_termination", "Unnamed: 32"], axis = 1)
attrition
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0      37       Yes  Travel_Rarely  Research & Development                 2
# 1      21        No  Travel_Rarely  Research & Development                15
# 2      45        No  Travel_Rarely  Research & Development                 6
# 3      23        No  Travel_Rarely                   Sales                 2
# 4      22        No  Travel_Rarely  Research & Development                15
# ...   ...       ...            ...                     ...               ...
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
#       Gender  JobInvolvement  JobLevel                    JobRole  \
# 0       Male               2         1      Laboratory Technician
# 1       Male               3         1         Research Scientist
# 2       Male               3         3          Research Director
# 3       Male               3         1       Sales Representative
# 4     Female               3         1      Laboratory Technician
# ...      ...             ...       ...                        ...
# 1465    Male               2         4                    Manager
# 1466    Male               3         5                    Manager
# 1467    Male               2         5                    Manager
# 1468    Male               3         4            Sales Executive
# 1469  Female               3         3  Healthcare Representative
#
#       JobSatisfaction  ... YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   3  ...                       0                     0
# 1                   4  ...                       0                     0
# 2                   1  ...                       0                     0
# 3                   1  ...                       0                     0
# 4                   4  ...                       0                     0
# ...               ...  ...                     ...                   ...
# 1465                1  ...                       1                    16
# 1466                1  ...                       4                    13
# 1467                4  ...                       2                    13
# 1468                3  ...                       1                     8
# 1469                4  ...                      15                     6
#
#       Higher_Education   Status_of_leaving  Mode_of_work  Leaves  Absenteeism  \
# 0           Graduation              Salary        OFFICE       4            2
# 1           Graduation       Work Accident           WFH       5            2
# 2      Post-Graduation           Dept.Head           WFH       1            3
# 3                  PHD       Work Accident        OFFICE       1            0
# 4                  PHD  Better Opportunity           WFH       5            2
# ...                ...                 ...           ...     ...          ...
# 1465   Post-Graduation              Salary        OFFICE       3            2
# 1466   Post-Graduation       Work Accident           WFH       1            1
# 1467   Post-Graduation       Work Accident        OFFICE       2            1
# 1468               PHD    Work Environment           WFH       2            2
# 1469              12th    Work Environment           WFH       4            3
#
#       Work_accident  Source_of_Hire   Job_mode
# 0                No       Job Event   Contract
# 1                No       Recruiter  Part Time
# 2                No       Job Event   Contract
# 3               Yes       Recruiter   FullTime
# 4                No       Job Event   Contract
# ...             ...             ...        ...
# 1465             No      Job Portal  Part Time
# 1466             No         Walk-in   FullTime
# 1467             No       Recruiter  Part Time
# 1468            Yes       Job Event  Part Time
# 1469            Yes      Job Portal   FullTime
#
# [1470 rows x 30 columns]

# %% [markdown]
# ## Next step...Recoding variables
# ### Recode the following variables chosen for analysis:
# ### 'Age', 'Attrition', 'Department', 'DistanceFromHome', 'Gender', 'MonthlyIncome','Higher_Education'

# %%
# Use .describe() to get stats on the min and max for the 'Age' so we can break the data down evenly into bins if possible. 
attrition['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Recode function for 'Age'
# * 1 = Under 22 = Gen Z
# * 2 = 23 - 38 = Millenials
# * 3 = 39 - 54 = Gen X
# * 4 = 55 - 74 = Baby Boomers

# %%
# Recode function for 'Age'
def Age(a):
        if a <= 22:
            return 1
        elif a > 22 and a <= 38:
            return 2
        elif a > 38 and a <= 54:
            return 3
        elif a >54:
            return 4
        else:
            return 5

# %%
# View min/max 
attrition['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
# use .value_counts() to see the levels for 'Attrition'
attrition['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# ### Recode function for 'Attrition'
# * 1 = No = Did NOT quit their job
# * 0 = Yes = Quit their job
# * False for anything other than 0 or 1 present

# %%
# Recode function for 'Attrition'
def Attrit(a):
    if a == 'No':
        return 1
    elif a == 'Yes':
        return 0
    else:
        return False

# %%
# use .value_counts() to see the levels for 'Department'
attrition['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# ### Recode function for 'Department'
# * 1 = Research & Development
# * 2 = Sales
# * 3 = Human Resources
# * False for anything else

# %%
def Dep(a):
        if a == "Research & Development":
            return 1
        elif a == "Sales":
            return 2
        elif a == "Human Resources":
            return 3
        else:
            return False

# %%
# Use .describe() to get stats on the min and max for the 'DistanceFromHome' so we can break the data down evenly into bins if possible. 
attrition['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# ### Recode function for 'DistanceFromHome'
# * 1 = <= 5
# * 2 = 6 - 10
# * 3 = 11 - 15
# * 4 = 16 - 20
# * 5 = 21 - 25
# * 6 = 26 - 30
# * 7 = anything else

# %%
def DistanceFromHome(d):
        if d <= 5:
            return 1
        elif d > 5 and d <= 10:
            return 2
        elif d > 10 and d <= 15:
            return 3
        elif d > 15 and d <= 20:
            return 4
        elif d > 20 and d <= 25:
            return 5
        elif d > 25 and d <= 30:
            return 6
        else:
            return 7

# %%
# use .value_counts() to see the levels for "Gender"
attrition['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Recode function for 'Gender'
# * 0 = Male
# * 1 = Female
# * 2 = Anything else

# %%
def Gender(g):
        if g == 'Male':
            return 0
        elif g == 'Female':
            return 1
        else: 
            return 2

# %%
# Use .describe() to get stats on the min and max for the 'MonthlyIncome' so we can break the data down evenly into bins if possible. 
attrition['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ### Recode function for 'MonthlyIncome'
# * 1 = 0 - 4000 per month
# * 2 = 4001 - 8000
# * 3 = 8001 - 12000
# * 4 = 12001 - 16000
# * 5 = 16001 - 20000
# * 0 = anything else

# %%
# Recode function for 'MonthlyIncome'
def Income(i):
    if i <= 4000:
        return 1
    elif i > 4000 and i <= 8000:
        return 2
    elif i > 8001 and i <= 12000:
        return 3
    elif i > 12001 and i <= 16000:
        return 4
    elif i > 16001 and i <= 20000:
        return 5
    else:
        return 0

# %%
# use .value_counts() to see the levels for Higher_Education
attrition['Higher_Education'].value_counts()
# Out:
# Post-Graduation    387
# Graduation         367
# PHD                358
# 12th               358
# Name: Higher_Education, dtype: int64

# %% [markdown]
# ### Recode function for 'Higher_Education'
# * 1 = 12th = High School Grad
# * 2 = Graduate = Bachelors degree
# * 3 = Post-Graduate = Masters Degree
# * 4 = PhD = Doctorate
# * 0 = Anything Else

# %%
def ed(e):
    if e == '12th':
        return 1
    elif e == 'Graduation':
        return 2
    elif e == 'Post-Graduation':
        return 3
    elif e == 'PHD':
        return 4
    else:
        return 0

# %% [markdown]
# # Run the functions!

# %%
attrition['AgeR'] = attrition['Age'].apply(Age)
attrition['AttritionR'] = attrition['Attrition'].apply(Attrit)
attrition['DepartmentR'] = attrition['Department'].apply(Dep)
attrition['DistanceFromHomeR'] = attrition['DistanceFromHome'].apply(DistanceFromHome)
attrition['GenderR'] = attrition['Gender'].apply(Gender)
attrition['MonthlyIncomeR'] = attrition['MonthlyIncome'].apply(Income)
attrition['Higher_EducationR'] = attrition['Higher_Education'].apply(ed)

# %% [markdown]
#  'Age', 'Attrition', 'Department', 'DistanceFromHome', 'Gender', 'MonthlyIncome','Higher_Education'

# %%
attrition
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0      37       Yes  Travel_Rarely  Research & Development                 2
# 1      21        No  Travel_Rarely  Research & Development                15
# 2      45        No  Travel_Rarely  Research & Development                 6
# 3      23        No  Travel_Rarely                   Sales                 2
# 4      22        No  Travel_Rarely  Research & Development                15
# ...   ...       ...            ...                     ...               ...
# 1465   52        No  Travel_Rarely                   Sales                 3
# 1466   55        No  Travel_Rarely  Research & Development                 1
# 1467   55        No  Travel_Rarely                   Sales                26
# 1468   58        No  Travel_Rarely                   Sales                10
# 1469   58       Yes  Travel_Rarely  Research & Development                23
#
#       Gender  JobInvolvement  JobLevel                    JobRole  \
# 0       Male               2         1      Laboratory Technician
# 1       Male               3         1         Research Scientist
# 2       Male               3         3          Research Director
# 3       Male               3         1       Sales Representative
# 4     Female               3         1      Laboratory Technician
# ...      ...             ...       ...                        ...
# 1465    Male               2         4                    Manager
# 1466    Male               3         5                    Manager
# 1467    Male               2         5                    Manager
# 1468    Male               3         4            Sales Executive
# 1469  Female               3         3  Healthcare Representative
#
#       JobSatisfaction  ... Work_accident  Source_of_Hire   Job_mode AgeR  \
# 0                   3  ...            No       Job Event   Contract    2
# 1                   4  ...            No       Recruiter  Part Time    1
# 2                   1  ...            No       Job Event   Contract    3
# 3                   1  ...           Yes       Recruiter   FullTime    2
# 4                   4  ...            No       Job Event   Contract    1
# ...               ...  ...           ...             ...        ...  ...
# 1465                1  ...            No      Job Portal  Part Time    3
# 1466                1  ...            No         Walk-in   FullTime    4
# 1467                4  ...            No       Recruiter  Part Time    4
# 1468                3  ...           Yes       Job Event  Part Time    4
# 1469                4  ...           Yes      Job Portal   FullTime    4
#
#       AttritionR  DepartmentR  DistanceFromHomeR  GenderR  MonthlyIncomeR  \
# 0              0            1                  1        0               1
# 1              1            1                  3        0               1
# 2              1            1                  2        0               4
# 3              1            2                  1        0               1
# 4              1            1                  3        1               1
# ...          ...          ...                ...      ...             ...
# 1465           1            2                  1        0               5
# 1466           1            1                  1        0               5
# 1467           1            2                  6        0               5
# 1468           1            2                  2        0               4
# 1469           0            1                  5        1               3
#
#       Higher_EducationR
# 0                     2
# 1                     2
# 2                     3
# 3                     4
# 4                     4
# ...                 ...
# 1465                  3
# 1466                  3
# 1467                  3
# 1468                  4
# 1469                  1
#
# [1470 rows x 37 columns]

# %% [markdown]
# #  Exploratory Analysis

# %% [markdown]
# ## Check distribution of the variables using .hist()
# ### 'Age', 'Attrition', 'Department', 'DistanceFromHome', 'Gender', 'MonthlyIncome','Higher_Education'

# %%
attrition.hist(figsize=(20,20),color = 'aquamarine', edgecolor= "black", linewidth= 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Exploratory Data Visualization of specific variables for analysis using sns.pairplot()
# ### Dataset is otherwise too large for viewing all 33 variables
# ### 'Age', 'Attrition', 'Department', 'DistanceFromHome', 'Gender', 'MonthlyIncome','Higher_Education'

# %%
sns.pairplot(attrition, vars=['Age', 'DepartmentR', 'DistanceFromHome', 'GenderR', 'MonthlyIncome', 'Higher_EducationR'], hue="Attrition")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Reference images for determining normality and performing data transformations if indicated
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Transforming _Negatively Skewed_ Data**
# The baseline on the chart above is 1. That would be your data left alone, with no transformation. Go up from one to a power of two or three, and those transformations will help with negatively skewed data. The higher the power, the stronger the transformation; so start small and work your way up.
#
# **Transforming _Positively Skewed_ Data**
# Go down from one, and the next two transformations (power 1/2 and 0) are meant to help with positively skewed data. The smaller the power and the farther away from one, the stronger the transformation.
#
# **Transforming Data with the Reciprocal**
# Lastly, there are two negative value powers, which have you take the reciprocal. Those are for flipping your data, or reversing the direction it goes in.
#
# **Prescribing Transformations**
# Below is a figure that provides the original, non-parametric data, and the most likely transformation to use. For instance, if your data looks like the upper left picture, positively skewed but not very kurtotic, try a square root transformation.

# %% [markdown]
# ## Perform Transformations
# ### Using the graphics above and visualizing the distribution of the variables with .distplot() histogram
# ### 'AgeR', 'Attrition', 'Department', 'DistanceFromHomeR', 'Gender', 'MonthlyIncomeR','Higher_EducationR'

# %%
####  REMOVE THIS ? ####

# REDO WITH THE RECODED DATA

# Create a new variable for the difference between mean and mode. We want this to be as close to zero as possible.
## AgeDiff = attrition['Age'].mean() - attrition['Age'].mode()
## AgeDiff

## mean > mode means there is a positive skew, meaning we have to do a square root

# %% [markdown]
# #### Variable:  'AgeR'

# %%
# plot histogram to see distribution

sns.distplot(attrition['Age'], hist_kws= dict(color = 'aquamarine', edgecolor= 'black', linewidth= 2))
plt.title('Attrition', fontsize= 18)
plt.xlabel('Age', fontsize= 16)
plt.ylabel('Density', fontsize= 16)
# Out:
# Text(0, 0.5, 'Density')

# %%
# 'AgeR' is approximately normally distributed. No transformation needed.

# %%
#### REMOVE THIS#####

# Creating a new variable for the square root of "Age", Then plot it.
# attrition['AgeSQRT'] = np.sqrt(attrition['Age'])
# sns.distplot(attrition['AgeSQRT'])

# AgeSQRTDiff = attrition['AgeSQRT'].mean() - attrition['AgeSQRT'].mode()
# AgeSQRTDiff

# The mean is .114 above the mode, meaning its closer to normalized than the original data
# We're gonna use ** AgeSQRT ** instead of the original data

# %%
# attrition['Age'].describe()

# %%
sns.distplot(attrition['DistanceFromHome'], hist_kws= dict(color = 'aquamarine', edgecolor= 'black', linewidth= 2))
plt.title('Attrition', fontsize= 18)
plt.xlabel('DistanceFromHome', fontsize= 16)
plt.ylabel('Density', fontsize= 16)
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.distplot(attrition['GenderR'], hist_kws= dict(color = 'aquamarine', edgecolor= 'black', linewidth= 2))
plt.title('Attrition', fontsize= 18)
plt.xlabel('GenderR', fontsize= 16)
plt.ylabel('Density', fontsize= 16)
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.distplot(attrition['MonthlyIncome'], hist_kws= dict(color = 'aquamarine', edgecolor= 'black', linewidth= 2))
plt.title('Attrition', fontsize= 18)
plt.xlabel('MonthlyIncome', fontsize= 16)
plt.ylabel('Density', fontsize= 16)
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.distplot(attrition['Higher_EducationR'], hist_kws= dict(color = 'aquamarine', edgecolor= 'black', linewidth= 2))
plt.title('Attrition', fontsize= 18)
plt.xlabel('Higher_EducationR', fontsize= 16)
plt.ylabel('Density', fontsize= 16)
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# ## Independent Chi-Square Analysis
# * To determine if the variables: 'AgeR', 'DepartmentR', 'DistanceFromHomeR', 'GenderR', 'MonthlyIncomeR','Higher_EducationR' influence Attrition.
# * Before running chi-square testing, create crosstab/contingency table to generate expected frequencies for the analysis and review that values in the array are all greater than 5

# %%
attrition_crosstab = pd.crosstab(attrition['DistanceFromHomeR'], attrition['Attrition'])

# %%
attrition_crosstab
# Out:
# Attrition           No  Yes
# DistanceFromHomeR
# 1                  545   87
# 2                  337   57
# 3                   90   25
# 4                  102   23
# 5                   85   32
# 6                   74   13

# %%
stats.chi2_contingency(attrition_crosstab)
# Out:
# (17.552928199740194,
#  0.0035621928630322707,
#  5,
#  array([[530.10612245, 101.89387755],
#         [330.47755102,  63.52244898],
#         [ 96.45918367,  18.54081633],
#         [104.84693878,  20.15306122],
#         [ 98.13673469,  18.86326531],
#         [ 72.97346939,  14.02653061]]))

# %%
# pval = 0.0035621928630322707 which is less than .05
# all expected frequency counts are above 5
# There is a significant influence between DistanceFromHome and Attrition

# %% [markdown]
# ### Recode Key for 'DistanceFromHome'
# * 1 = <= 5
# * 2 = 6 - 10
# * 3 = 11 - 15
# * 4 = 16 - 20
# * 5 = 21 - 25
# * 6 = 26 - 30
# * 7 = anything else

# %%
sns.countplot(x = "DistanceFromHomeR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='DistanceFromHomeR', ylabel='count'>

# %%
attrition_crosstab2 = pd.crosstab(attrition['AgeR'], attrition['Attrition'])

# %%
attrition_crosstab2
# Out:
# Attrition   No  Yes
# AgeR
# 1           30   27
# 2          702  147
# 3          443   52
# 4           58   11

# %%
stats.chi2_contingency(attrition_crosstab2)
# Out:
# (53.595755680890704,
#  1.3684295600664271e-11,
#  3,
#  array([[ 47.81020408,   9.18979592],
#         [712.12040816, 136.87959184],
#         [415.19387755,  79.80612245],
#         [ 57.8755102 ,  11.1244898 ]]))

# %%
# pval = 1.3684295600664271e-11 which is less than .05
# all expected frequency counts are above 5
# There is a significant influence between Age and Attrition

# %% [markdown]
# ### Recode Key for 'Age'
# * 1 = <=   22  = Gen Z
# * 2 = 23 - 38 = Millenials
# * 3 = 39 - 54 = Gen X
# * 4 = 55 - 74 = Baby Boomers

# %%
sns.countplot(x = "AgeR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='AgeR', ylabel='count'>

# %%
attrition_crosstab3 = pd.crosstab(attrition['DepartmentR'], attrition['Attrition'])

# %%
attrition_crosstab3
# Out:
# Attrition     No  Yes
# DepartmentR
# 1            828  133
# 2            354   92
# 3             51   12

# %%
stats.chi2_contingency(attrition_crosstab3)
# Out:
# (10.796007322410668,
#  0.004525606574479639,
#  2,
#  array([[806.06326531, 154.93673469],
#         [374.09387755,  71.90612245],
#         [ 52.84285714,  10.15714286]]))

# %%
# pval = 0.004525606574479639 which is less than .05
# all expected frequency counts are above 5
# There is a significant influence between Department and Attrition

# %% [markdown]
# ### Recode Key for 'Department'
# * 1 = Research & Development
# * 2 = Sales
# * 3 = Human Resources
# * False for anything else

# %%
sns.countplot(x = "DepartmentR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='DepartmentR', ylabel='count'>

# %%
attrition_crosstab4 = pd.crosstab(attrition['GenderR'], attrition['Attrition'])

# %%
attrition_crosstab4
# Out:
# Attrition   No  Yes
# GenderR
# 0          732  150
# 1          501   87

# %%
stats.chi2_contingency(attrition_crosstab4)
# Out:
# (1.1169671241970978,
#  0.29057244902890855,
#  1,
#  array([[739.8, 142.2],
#         [493.2,  94.8]]))

# %%
# pval = 0.29057244902890855 and is not less than .05
# all expected frequency counts are above 5
# There is NOT a significant influence between Gender and Attrition

# %% [markdown]
# ### Recode Key for 'Gender'
# * 0 = Male
# * 1 = Female
# * 2 = Anything else

# %%
sns.countplot(x = "GenderR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='GenderR', ylabel='count'>

# %%
attrition_crosstab5 = pd.crosstab(attrition['MonthlyIncomeR'], attrition['Attrition'])

# %%
attrition_crosstab5
# Out:
# Attrition        No  Yes
# MonthlyIncomeR
# 1               406  137
# 2               486   60
# 3               157   29
# 4                63    6
# 5               121    5

# %%
stats.chi2_contingency(attrition_crosstab5)
# Out:
# (60.564722151327345,
#  2.207177246381586e-12,
#  4,
#  array([[455.45510204,  87.54489796],
#         [457.97142857,  88.02857143],
#         [156.0122449 ,  29.9877551 ],
#         [ 57.8755102 ,  11.1244898 ],
#         [105.68571429,  20.31428571]]))

# %%
# pval = 2.207177246381586e-12 which is less than .05
# all expected frequency counts are above 5
# There is a significant influence between MontlhyIncome and Attrition

# %% [markdown]
# ### Recode Key for 'MonthlyIncome'
# * 1 = 0 - 4000 per month
# * 2 = 4001 - 8000
# * 3 = 8001 - 12000
# * 4 = 12001 - 16000
# * 5 = 16001 - 20000
# * 0 = anything else

# %%
sns.countplot(x = "MonthlyIncomeR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='MonthlyIncomeR', ylabel='count'>

# %%
attrition_crosstab6 = pd.crosstab(attrition['Higher_EducationR'], attrition['Attrition'])

# %%
attrition_crosstab6
# Out:
# Attrition           No  Yes
# Higher_EducationR
# 1                  300   58
# 2                  309   58
# 3                  323   64
# 4                  301   57

# %%
stats.chi2_contingency(attrition_crosstab6)
# Out:
# (0.08914232682512083,
#  0.9931077635408382,
#  3,
#  array([[300.28163265,  57.71836735],
#         [307.83061224,  59.16938776],
#         [324.60612245,  62.39387755],
#         [300.28163265,  57.71836735]]))

# %%
# pval = 0.9931077635408382 and is not less than .05
# all expected frequency counts are above 5
# There is NOT a significant influence between Higher_Education and Attrition

# %%
# Independent Chi-Square testing reveals that Age, Department, DistanceFromHome, and MonthlyIncome have a significant influence on attrition while, 
# Gender and Higher_Education do NOT.

# %% [markdown]
# ### Recode Key for 'Higher_Education'
# * 1 = 12th = High School Grad
# * 2 = Graduate = Bachelors degree
# * 3 = Post-Graduate = Masters Degree
# * 4 = PhD = Doctorate
# * 0 = Anything Else

# %%
sns.countplot(x = "Higher_EducationR", hue="Attrition", data = attrition)
# Out:
# <AxesSubplot:xlabel='Higher_EducationR', ylabel='count'>

# %% [markdown]
# ## Correlation matrix

# %%
attrition.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_f496d_row0_col0,#T_f496d_row1_col1,#T_f496d_row2_col2,#T_f496d_row3_col3,#T_f496d_row4_col4,#T_f496d_row5_col5,#T_f496d_row6_col6,#T_f496d_row7_col7,#T_f496d_row8_col8,#T_f496d_row9_col9,#T_f496d_row10_col10,#T_f496d_row11_col11,#T_f496d_row12_col12,#T_f496d_row13_col13,#T_f496d_row14_col14,#T_f496d_row15_col15,#T_f496d_row16_col16,#T_f496d_row17_col17,#T_f496d_row18_col18,#T_f496d_row19_col19,#T_f496d_row20_col20,#T_f496d_row21_col21,#T_f496d_row22_col22,#T_f496d_row23_col23{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col1,#T_f496d_row2_col10,#T_f496d_row3_col2,#T_f496d_row3_col16,#T_f496d_row3_col23,#T_f496d_row4_col21,#T_f496d_row5_col4,#T_f496d_row5_col23,#T_f496d_row7_col14,#T_f496d_row8_col15,#T_f496d_row9_col5,#T_f496d_row9_col7,#T_f496d_row9_col22,#T_f496d_row11_col20,#T_f496d_row15_col1,#T_f496d_row16_col4,#T_f496d_row16_col14,#T_f496d_row21_col2,#T_f496d_row22_col1{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col2,#T_f496d_row1_col15,#T_f496d_row2_col14,#T_f496d_row4_col3,#T_f496d_row7_col4,#T_f496d_row8_col14,#T_f496d_row9_col0,#T_f496d_row10_col8,#T_f496d_row11_col19,#T_f496d_row13_col8,#T_f496d_row15_col19,#T_f496d_row16_col13,#T_f496d_row19_col16,#T_f496d_row21_col8,#T_f496d_row23_col8,#T_f496d_row23_col11,#T_f496d_row23_col18{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col3,#T_f496d_row22_col12{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_f496d_row0_col4,#T_f496d_row0_col16,#T_f496d_row0_col19,#T_f496d_row2_col3,#T_f496d_row3_col11,#T_f496d_row7_col2,#T_f496d_row7_col23,#T_f496d_row9_col8,#T_f496d_row13_col4,#T_f496d_row15_col20,#T_f496d_row17_col19,#T_f496d_row23_col13{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col5,#T_f496d_row5_col0{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_f496d_row0_col6,#T_f496d_row17_col12{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_f496d_row0_col7,#T_f496d_row2_col16,#T_f496d_row4_col17,#T_f496d_row5_col15,#T_f496d_row7_col11,#T_f496d_row7_col15,#T_f496d_row7_col16,#T_f496d_row8_col0,#T_f496d_row8_col4,#T_f496d_row9_col3,#T_f496d_row9_col12,#T_f496d_row9_col13,#T_f496d_row9_col15,#T_f496d_row11_col10,#T_f496d_row16_col5,#T_f496d_row17_col7,#T_f496d_row17_col21,#T_f496d_row21_col9,#T_f496d_row22_col9,#T_f496d_row23_col0,#T_f496d_row23_col17{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col8,#T_f496d_row4_col14,#T_f496d_row4_col16,#T_f496d_row7_col6,#T_f496d_row8_col18,#T_f496d_row8_col23,#T_f496d_row9_col4,#T_f496d_row9_col10,#T_f496d_row9_col11,#T_f496d_row10_col4,#T_f496d_row10_col7,#T_f496d_row11_col1,#T_f496d_row16_col19,#T_f496d_row20_col11,#T_f496d_row22_col15,#T_f496d_row22_col20{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col9,#T_f496d_row0_col21,#T_f496d_row1_col23,#T_f496d_row2_col17,#T_f496d_row3_col15,#T_f496d_row8_col20,#T_f496d_row9_col1,#T_f496d_row10_col20,#T_f496d_row11_col13,#T_f496d_row11_col23,#T_f496d_row13_col21,#T_f496d_row15_col2,#T_f496d_row15_col6,#T_f496d_row15_col23,#T_f496d_row19_col6{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_f496d_row0_col10{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_f496d_row0_col11,#T_f496d_row2_col4,#T_f496d_row2_col12,#T_f496d_row2_col13,#T_f496d_row5_col11,#T_f496d_row6_col14,#T_f496d_row22_col4{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col12{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_f496d_row0_col13,#T_f496d_row13_col17{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_f496d_row0_col14,#T_f496d_row18_col0,#T_f496d_row18_col5{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_f496d_row0_col15,#T_f496d_row1_col5,#T_f496d_row2_col0,#T_f496d_row2_col23,#T_f496d_row4_col8,#T_f496d_row5_col21,#T_f496d_row6_col4,#T_f496d_row6_col23,#T_f496d_row8_col1,#T_f496d_row10_col9,#T_f496d_row11_col4,#T_f496d_row11_col7,#T_f496d_row11_col14,#T_f496d_row11_col16,#T_f496d_row15_col9,#T_f496d_row16_col17,#T_f496d_row17_col2,#T_f496d_row17_col15,#T_f496d_row19_col2,#T_f496d_row19_col9,#T_f496d_row20_col5,#T_f496d_row20_col23{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col17,#T_f496d_row17_col0{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_f496d_row0_col18{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_f496d_row0_col20,#T_f496d_row3_col4,#T_f496d_row4_col2,#T_f496d_row4_col10,#T_f496d_row5_col9,#T_f496d_row7_col21,#T_f496d_row8_col9,#T_f496d_row8_col12,#T_f496d_row10_col23,#T_f496d_row13_col11,#T_f496d_row16_col3,#T_f496d_row16_col8,#T_f496d_row16_col12,#T_f496d_row16_col23,#T_f496d_row17_col8,#T_f496d_row18_col6{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_f496d_row0_col22,#T_f496d_row3_col17,#T_f496d_row22_col0{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_f496d_row0_col23,#T_f496d_row1_col18,#T_f496d_row2_col8,#T_f496d_row3_col7,#T_f496d_row4_col6,#T_f496d_row5_col7,#T_f496d_row6_col12,#T_f496d_row7_col3,#T_f496d_row7_col12,#T_f496d_row7_col19,#T_f496d_row8_col2,#T_f496d_row8_col19,#T_f496d_row9_col19,#T_f496d_row9_col21,#T_f496d_row10_col16,#T_f496d_row11_col6,#T_f496d_row12_col6,#T_f496d_row13_col6,#T_f496d_row13_col23,#T_f496d_row14_col6,#T_f496d_row15_col4,#T_f496d_row16_col10,#T_f496d_row17_col4,#T_f496d_row17_col23,#T_f496d_row18_col1,#T_f496d_row18_col19,#T_f496d_row18_col20,#T_f496d_row19_col18,#T_f496d_row20_col18,#T_f496d_row21_col23,#T_f496d_row22_col7,#T_f496d_row22_col11,#T_f496d_row23_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f496d_row1_col0,#T_f496d_row1_col21,#T_f496d_row1_col22,#T_f496d_row3_col21,#T_f496d_row4_col7,#T_f496d_row6_col13,#T_f496d_row7_col1,#T_f496d_row9_col17,#T_f496d_row11_col9,#T_f496d_row12_col7,#T_f496d_row15_col10,#T_f496d_row15_col11,#T_f496d_row15_col12,#T_f496d_row15_col16,#T_f496d_row18_col23,#T_f496d_row19_col1,#T_f496d_row19_col20,#T_f496d_row19_col21,#T_f496d_row20_col19,#T_f496d_row20_col22,#T_f496d_row21_col5,#T_f496d_row21_col16,#T_f496d_row23_col15{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_f496d_row1_col2,#T_f496d_row1_col12,#T_f496d_row1_col13,#T_f496d_row5_col19,#T_f496d_row6_col1,#T_f496d_row6_col20,#T_f496d_row17_col9,#T_f496d_row19_col13,#T_f496d_row19_col15,#T_f496d_row20_col12,#T_f496d_row20_col21,#T_f496d_row21_col22,#T_f496d_row23_col2{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_f496d_row1_col3,#T_f496d_row1_col10,#T_f496d_row1_col19,#T_f496d_row7_col20,#T_f496d_row10_col15,#T_f496d_row14_col4,#T_f496d_row14_col16,#T_f496d_row15_col0,#T_f496d_row15_col17,#T_f496d_row16_col15,#T_f496d_row16_col20,#T_f496d_row16_col21,#T_f496d_row19_col14,#T_f496d_row20_col0,#T_f496d_row20_col2,#T_f496d_row20_col3,#T_f496d_row21_col0,#T_f496d_row21_col3,#T_f496d_row21_col6,#T_f496d_row21_col11,#T_f496d_row23_col9,#T_f496d_row23_col12{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_f496d_row1_col4,#T_f496d_row6_col18,#T_f496d_row9_col20,#T_f496d_row13_col18,#T_f496d_row15_col3,#T_f496d_row15_col14,#T_f496d_row15_col21,#T_f496d_row16_col1,#T_f496d_row18_col8,#T_f496d_row21_col12,#T_f496d_row21_col14,#T_f496d_row21_col18{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_f496d_row1_col6,#T_f496d_row2_col15,#T_f496d_row4_col5,#T_f496d_row4_col19,#T_f496d_row6_col11,#T_f496d_row8_col13,#T_f496d_row9_col6,#T_f496d_ro

# %%
# correlation value between 0 and 1, positive or negative, 
# The larger the correlation value, the more closely related the two variables are.
# positive = directly proportional
# negative = inversely proportional

# %% [markdown]
# ### Correlation Matrix Results
# ### The following variables are closely related to each other:
# * Age and TotalWorkingYears = 0.68
# * JobLevel and TotalWorkingYears = 0.78
# * JobLevel and MonthlyIncome = 0.95
# * MonthlyIncome and TotalWorkingYears = 0.77
# * PercentSalaryHike and PerformanceRating = 0.77
# * TotalWorkingYears and YearsAtCompany = 0.63
# * YearsAtCompany and YearsSinceLastPromotion = 0.62
# * YearsAtCompany and YearsWithCurrManager = 0.77
#
# ### The following variables appear to have little to no relationship:
# * DistanceFromHome
# * JobInvolvement
# * JobSatisfaction
# * NumCompaniesWorked
# * StockOptionLevel
# * TrainingTimesLastYear
# * Leaves
# * Absenteeism

# %%
# using seaborn

# %%
# remove later, not helpful due to shape of data, too many variables
sns.heatmap(attrition.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
attrition.mean()
# Out:
# Age                          36.923810
# DistanceFromHome              9.192517
# JobInvolvement                2.729932
# JobLevel                      2.063946
# JobSatisfaction               2.728571
# MonthlyIncome              6502.931293
# NumCompaniesWorked            2.693197
# PercentSalaryHike            15.209524
# PerformanceRating             3.153741
# StockOptionLevel              0.793878
# TotalWorkingYears            11.279592
# TrainingTimesLastYear         2.799320
# YearsAtCompany                7.008163
# YearsSinceLastPromotion       2.187755
# YearsWithCurrManager          4.123129
# Leaves                        2.568707
# Absenteeism                   1.525170
# AgeR                          2.391837
# AttritionR                    0.838776
# DepartmentR                   1.389116
# DistanceFromHomeR             2.293878
# GenderR                       0.400000
# MonthlyIncomeR                2.108163
# Higher_EducationR             2.506803
# dtype: float64

# %%
# To be continued.....
# Working on categorical variable visualization with boxplots?

# %%
# remove later, not needed, other visuals in Tableau
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x= "AgeR", y="TotalWorkingYears", hue="Attrition", palette=["m", "g"], data=attrition)
sns.despine(offset=10, trim=True)
